# %% [markdown]
# # Week 3 — Read code you didn't write
# *Albania Now — a Free Focus program, built with Chicago First. Run cells top to bottom. First: **File → Save a copy in Drive**.*
#
# **The rule of this notebook:** store your prediction BEFORE running the program cell. The CHECK compares your committed prediction to reality — that comparison is the entire lesson.
#
# Three programs by another author. For each: read COLD first — names, load-bearing line, smells — and answer before running.

# %% [markdown]
# ## Program 1 — the receipt totaler
# Read it. Do NOT run yet.

# %%
# by another author
cmimet = [250, 120, 480, 95]
total = 0
for cmim in cmimet:
    total = total + cmim
zbritja = total * 0.10
print("Pagesa:", total - zbritja)

# %%
# PREDICT — what number does it print?
pred_1 = None

# %%
# CHECK 1
assert pred_1 is not None, "commit first"
assert pred_1 == 850.5, f"you predicted {pred_1!r} — trace the discount line again"
print("PASSED")

# %% [markdown]
# *Smell check: the 0.10 is a magic number — nothing says why 10%.*

# %% [markdown]
# ## Program 2 — the temperature converter
# Read cold. One of these two programs (2 or 3) hides a real bug.

# %%
# by another author
celsius = 25
fahrenheit = celsius * 9 / 5 + 32
print(celsius, "C =", fahrenheit, "F")

# %%
# PREDICT — the fahrenheit value it prints
pred_2 = None

# %%
# CHECK 2
assert pred_2 is not None, "commit first"
assert pred_2 == 77.0, f"you predicted {pred_2!r} — 25 * 9 / 5 + 32, left to right"
print("PASSED")

# %% [markdown]
# ## Program 3 — the word counter
# Read cold. The author CLAIMS it counts how many words are longer than 3 letters.

# %%
# by another author — claimed: counts words longer than 3 letters
fjalia = "sot eshte nje dite shume e mire"
numri = 0
for fjale in fjalia.split():
    if len(fjale) > 3:
        numri = numri + 1
print("fjale te gjata:", numri)

# %%
# PREDICT — the number it prints (count by hand: sot/eshte/nje/dite/shume/e/mire)
pred_3 = None

# %%
# CHECK 3
assert pred_3 is not None, "commit first"
assert pred_3 == 3, f"you predicted {pred_3!r} — which words have MORE than 3 letters (not 3 exactly)?"
print("PASSED — eshte, dite, shume. The > is doing exactly what it says, not what you assume")

# %% [markdown]
# ## The build — the bug report
# One of the three programs behaves differently from its author's claim for some inputs. (Hint: what should the word counter do with the word `dite`? What does `> 3` versus `>= 3` mean for a claim that says 'longer than 3'? Is the claim or the code right? Decide — and check program 1's discount against a receipt of ONE item costing 100.) Write the report: claim, actual behavior with proving input, load-bearing line, one-line fix.

# %%
# your investigation space
