# %% [markdown]
# # Week 1 — Code in your browser
# *Albania Now — a Free Focus program, built with Chicago First. Run cells top to bottom. First: **File → Save a copy in Drive**.*

# %% [markdown]
# ## 1. Press play
# Click the cell below, then the play button (or Shift+Enter).

# %%
print("Hello from a Google computer")

# %% [markdown]
# The code ran in a data center, not on your machine. Only the text came back.

# %% [markdown]
# ## 2. Python is a calculator that reads

# %%
2026 - 2010   # the last line of a cell shows its value

# %%
print("If you were born in 2010 you are", 2026 - 2010, "years old")

# %% [markdown]
# ## 3. Variables — names for values

# %%
city = "Tirana"
people = 560000
print(city, "has about", people, "people")

# %% [markdown]
# **Your turn:** make variables for YOUR town and something you know about it, and print a sentence using them.

# %%
# your turn

# %% [markdown]
# ## 4. Text vs numbers
# `7` is a number. `"7"` is text. Watch both behave:

# %%
print(7 + 7)        # math
print("7" + "7")    # gluing text

# %% [markdown]
# ## 5. Read one report on purpose
# Run this broken cell. Do not fix it yet — READ the red text first: what stopped it, which line, what does it suggest?

# %%
print("age: " + 16)   # run it, read the report, THEN fix it

# %% [markdown]
# Fix: turn the number into text with `str(16)`, or use a comma instead of `+`.

# %% [markdown]
# ## 6. The build — 500 times
# Make the computer print a sentence about your town 500 times. You have not been taught how — ask an AI assistant or search, run what you get, and make sure you understand **every word** before keeping it. Then change it to print the numbers 1 to 500.
#
# **Turn-in:** screenshot of your cell and part of its output.

# %%
# the build
