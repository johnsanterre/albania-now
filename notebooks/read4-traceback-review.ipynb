# %% [markdown]
# # Week 4 — Read the traceback, write the review
# *Albania Now — a Free Focus program, built with Chicago First. Run cells top to bottom. First: **File → Save a copy in Drive**.*
#
# **The rule of this notebook:** store your prediction BEFORE running the program cell. The CHECK compares your committed prediction to reality — that comparison is the entire lesson.

# %% [markdown]
# ## Traceback drill 1
# Run it. Read the report BOTTOM-UP, then commit.

# %%
# broken on purpose — run and read the full chain
def total_line(cmimet):
    return "Total: " + sum(cmimet)

cmimet = [100, 200]
print(total_line(cmimet))

# %%
# PREDICT — which line number does the FIXING start on? (the line inside total_line)
pred_1 = None

# %%
# CHECK 1
assert pred_1 is not None, "commit first"
assert pred_1 == 2, f"you said line {pred_1!r} — climb to the line INSIDE the helper, where text met a number"
print("PASSED — fix: \"Total: \" + str(sum(cmimet))")

# %% [markdown]
# ## Traceback drill 2

# %%
# broken on purpose — a chain through two helpers
def mesatarja(numrat):
    return sum(numrat) / len(numrat)

def raport(numrat):
    return "Mesatarja: " + str(mesatarja(numrat))

print(raport([]))

# %%
# PREDICT — the KIND of error, as text: "NameError", "TypeError", "ZeroDivisionError", or "ValueError"
pred_2 = None

# %%
# CHECK 2
assert pred_2 is not None, "commit first"
assert pred_2 == "ZeroDivisionError", f"you said {pred_2!r} — the empty list has len 0, and the division meets it"
print("PASSED — and note the fix belongs in mesatarja: guard the empty case")

# %% [markdown]
# ## The review target
# A 20-line program that mostly works. Read it COLD — names, load-bearing lines, smells — before running. Your review has four parts: what it does, what's solid, what's wrong or smelly (line numbers + reasons; at least three findings exist), what you'd change first.

# %%
# by another author — the review target
notat = [8, 9, 6, 10, 7, 9]

total = 0
for nota in notat:
    total = total + nota
average = total
mesatarja = total / len(notat)

kalon = 0
for nota in notat:
    if nota > 5:
        kalon = kalon + 1

print("Mesatarja:", mesatarja)
print("Kalojne:", kalon, "nga", len(notat))
print("Nota me e larta:", max(notat))
shuma_e_katrorit = mesatarja * mesatarja * 0.25

# %% [markdown]
# **Findings to hunt** (do not read until you have three of your own): a lying name that stores the wrong thing, a computed value never used, a magic number with no explanation.

# %% [markdown]
# ## The build — the review + the fix
# Write the four-part review in the cell below (as a text cell), make your ONE first change to the program, and show it running. This completes the sprint.

# %% [markdown]
# **My review:**
# 1. What it does: …
# 2. Solid: …
# 3. Findings: …
# 4. First change: …

# %%
# the program, with your one change applied
