# %% [markdown]
# # Week 2 — Read the shapes
# *Albania Now — a Free Focus program, built with Chicago First. Run cells top to bottom. First: **File → Save a copy in Drive**.*
#
# **The rule of this notebook:** store your prediction BEFORE running the program cell. The CHECK compares your committed prediction to reality — that comparison is the entire lesson.
#
# New move this week: BEFORE the prediction, name the shape out loud — accumulator, or fork?

# %% [markdown]
# ### Drill 1
# Trace on paper, then commit:
#
# *name the shape first*

# %%
# PREDICT 1 — replace None with what the program will print
pred_1 = None

# %%
total = 0
for n in [4, 7, 2]:
    total = total + n
print(total)

# %%
# CHECK 1
assert pred_1 is not None, 'commit a prediction first'
assert pred_1 == 13, f'you predicted {pred_1!r} — the machine says otherwise: trace again'
print('PASSED — your trace matched the machine')

# %% [markdown]
# ### Drill 2
# Trace on paper, then commit:
#
# *an accumulator can count, not just sum*

# %%
# PREDICT 2 — replace None with what the program will print
pred_2 = None

# %%
numri = 0
for fjale in ["mire", "dita", "sot"]:
    numri = numri + 1
print(numri)

# %%
# CHECK 2
assert pred_2 is not None, 'commit a prediction first'
assert pred_2 == 3, f'you predicted {pred_2!r} — the machine says otherwise: trace again'
print('PASSED — your trace matched the machine')

# %% [markdown]
# ### Drill 3
# Trace on paper, then commit:
#
# *read the test first; predict the printed text in quotes*

# %%
# PREDICT 3 — replace None with what the program will print
pred_3 = None

# %%
mosha = 15
if mosha >= 16:
    print("mund te votosh ne disa vende")
else:
    print("jo ende")

# %%
# CHECK 3
assert pred_3 is not None, 'commit a prediction first'
assert pred_3 == "jo ende", f'you predicted {pred_3!r} — the machine says otherwise: trace again'
print('PASSED — your trace matched the machine')

# %% [markdown]
# ### Drill 4
# Trace on paper, then commit:
#
# *a fork with no else — what happens when the test is false?*

# %%
# PREDICT 4 — replace None with what the program will print
pred_4 = None

# %%
x = 9
if x > 5:
    x = x * 2
print(x)

# %%
# CHECK 4
assert pred_4 is not None, 'commit a prediction first'
assert pred_4 == 18, f'you predicted {pred_4!r} — the machine says otherwise: trace again'
print('PASSED — your trace matched the machine')

# %% [markdown]
# ### Drill 5
# Trace on paper, then commit:
#
# *accumulators build text too — watch the trailing space*

# %%
# PREDICT 5 — replace None with what the program will print
pred_5 = None

# %%
fjalia = ""
for fjale in ["sa", "mire"]:
    fjalia = fjalia + fjale + " "
print(fjalia)

# %%
# CHECK 5
assert pred_5 is not None, 'commit a prediction first'
assert pred_5 == "sa mire ", f'you predicted {pred_5!r} — the machine says otherwise: trace again'
print('PASSED — your trace matched the machine')

# %% [markdown]
# ### Drill 6
# Trace on paper, then commit:
#
# *both shapes at once: a loop that counts only some*

# %%
# PREDICT 6 — replace None with what the program will print
pred_6 = None

# %%
total = 0
for n in [3, 10, 4, 20]:
    if n > 5:
        total = total + n
print(total)

# %%
# CHECK 6
assert pred_6 is not None, 'commit a prediction first'
assert pred_6 == 30, f'you predicted {pred_6!r} — the machine says otherwise: trace again'
print('PASSED — your trace matched the machine')

# %% [markdown]
# ### Drill 7
# Trace on paper, then commit:
#
# *the find-the-biggest pattern — trace two passes, then decide*

# %%
# PREDICT 7 — replace None with what the program will print
pred_7 = None

# %%
i_madh = 0
for n in [12, 5, 19, 3]:
    if n > i_madh:
        i_madh = n
print(i_madh)

# %%
# CHECK 7
assert pred_7 is not None, 'commit a prediction first'
assert pred_7 == 19, f'you predicted {pred_7!r} — the machine says otherwise: trace again'
print('PASSED — your trace matched the machine')

# %% [markdown]
# ### Drill 8
# Trace on paper, then commit:
#
# *TWO adds inside the loop — indentation is structure*

# %%
# PREDICT 8 — replace None with what the program will print
pred_8 = None

# %%
x = 0
for n in [1, 2, 3]:
    x = x + n
    x = x + n
print(x)

# %%
# CHECK 8
assert pred_8 is not None, 'commit a prediction first'
assert pred_8 == 12, f'you predicted {pred_8!r} — the machine says otherwise: trace again'
print('PASSED — your trace matched the machine')

# %% [markdown]
# ## The build — the shape catalog
# Copy one accumulator and one fork from above into the cells below, each with a one-line purpose comment. Then write ONE program of your own that uses both shapes at once, purpose comment on top.

# %%
# my accumulator example + purpose

# %%
# my fork example + purpose

# %%
# my combined program
